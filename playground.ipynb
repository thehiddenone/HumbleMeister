# %%
import torch
print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 13.0
# True
# NVIDIA GeForce RTX 5090

# %%
import chess
import chess.svg

bb = chess.BaseBoard()

chess.svg.board(bb, size = 400)

# %%
# import and convert chess games

from humblemeister.data import ChessGameBank

#cgb = ChessGameBank()
#cgb.load_games('env/data/chess_pgn')
#cgb.evaluate_moves('env/data/chess_games_bank', 16)
#len(cgb)

# %%
# add value evals

from humblemeister.data import ChessGameBank

cgb = ChessGameBank()
cgb.fill_value_evals('env/data/chess_games_bank', 24)
# Out:
# filling value_evals in 524 shards with 24 workers
# HBox(children=(IntProgress(value=0, description='Filling:', max=524), HTML(value='<small>0 / 524 shards</small…

# %%
# load training dataset

from humblemeister.data import ChessGameBank

cgb = ChessGameBank()
cgb.load('env/data/chess_games_bank')
len(cgb)

# %%
import humblemeister.trainer as hmt
import torch.serialization                                                                                                                                                
                                                                                                                                                                        
torch.serialization.add_safe_globals([hmt.ChessTrainingConfig])

cfg = hmt.ChessTrainingConfig.giant('model_giant_04072026_2000_b3')
t = hmt.ChessTrainer(cfg, cgb, resume=True)
# Out:
# resumed from checkpoint_epoch_0400.pt (epoch 400, loss 3.5598)

# %%
t.run()
# Out:
# training on cuda
# model parameters: 687,066,624
#  38%|████████████████████████████▌                                               | 600/1599 [3:51:37<9:36:33, 34.63s/it]

# %%
moves, outcome, weights = cgb2.get_random_game()

# %%
moves, outcome, weights

# %%
from humblemeister import ChessEngine

# %%
engine = ChessEngine.load("env/out/model_huge_512b64_04042026_2000_b1")

# %%
engine.start_game()

# %%
engine.move('f1f8')
